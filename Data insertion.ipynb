# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading dataset

# %%
store_details = pd.read_csv('../Project/Datasets/store_details.csv')
store_details.head()
# Out:
#    store_id              store_name       phone                        email
# 0         1      FreshMart Downtown  6175551001       downtown@freshmart.com
# 1         2     FreshMart Riverside  6175551002      riverside@freshmart.com
# 2         3      GreenBasket Market  6175551003  hello@greenbasketmarket.com
# 3         4  UrbanGrocers South End  6175551004    southend@urbangrocers.com
# 4         5     QuickCart Brookline  6175551005      brookline@quickcart.com

# %%
store_address = pd.read_csv('../Project/Datasets/store_address.csv')
store_address.head()
# Out:
#             street        city          state country  zip_code  store_id
# 0      101 Main St      Boston  Massachusetts     USA      2108         1
# 1      22 River Rd   Cambridge  Massachusetts     USA      2139         2
# 2    15 Beacon Ave  Somerville  Massachusetts     USA      2143         3
# 3  88 Harrison Ave      Boston  Massachusetts     USA      2118         4
# 4       200 Elm St   Brookline  Massachusetts     USA      2445         5

# %%
store_staff = pd.read_csv('../Project/Datasets/store_staff.csv')
store_staff.head()
# Out:
#    emp_id       username password  store_id     role availability_status
# 0       1  olivia.parker  pass123         1  manager                 yes
# 1       2   chloe.martin  pass123         1   packer                 yes
# 2       3   jacob.turner  pass123         1   packer                 yes
# 3       4     grace.ward  pass123         1   packer                 yes
# 4       5  daniel.murphy  pass123         2  manager                 yes

# %%
store_mapping = pd.read_csv('../Project/Datasets/stores_mapping.csv')
store_mapping.head()
# Out:
#    store_id  inventory_id  product_id
# 0         1             1           1
# 1         1             2           2
# 2         1             3           3
# 3         1             4           4
# 4         1             5           5

# %%
category = pd.read_csv('../Project/Datasets/category.csv')
category.head()
# Out:
#    category_id   category_name                        category_description
# 0            1          Fruits                       Fresh seasonal fruits
# 1            2      Vegetables              Fresh produce and leafy greens
# 2            3           Dairy      Milk, yogurt, eggs, cheese, and butter
# 3            4          Bakery  Fresh breads, rolls, muffins, and pastries
# 4            5  Meat & Seafood                 White meat and seafood only

# %%
inventory = pd.read_csv('../Project/Datasets/inventory.csv')
inventory.head()
# Out:
#    inventory_id  quantity_available  reorder_level last_updated
# 0             1                   5              4   2026-03-29
# 1             2                  36              4   2026-03-29
# 2             3                  33              4   2026-03-29
# 3             4                  30              4   2026-03-29
# 4             5                  24              4   2026-03-29

# %%
product_images = pd.read_csv('../Project/Datasets/product_images.csv')
product_images.head()
# Out:
#    product_id                                        image_url  \
# 0           1              cdn.local/products/banana-bunch.jpg
# 1           2          cdn.local/products/gala-apples-3-lb.jpg
# 2           3          cdn.local/products/fuji-apples-3-lb.jpg
# 3           4        cdn.local/products/navel-oranges-4-lb.jpg
# 4           5  cdn.local/products/red-seedless-grapes-2-lb.jpg
#
#                         image_description
# 0              Banana Bunch product image
# 1          Gala Apples 3 lb product image
# 2          Fuji Apples 3 lb product image
# 3        Navel Oranges 4 lb product image
# 4  Red Seedless Grapes 2 lb product image

# %%
product = pd.read_csv('../Project/Datasets/product.csv')
product.head()
# Out:
#    product_id              product_name  product_barcode  \
# 0           1              Banana Bunch     100000000001
# 1           2          Gala Apples 3 lb     100000000002
# 2           3          Fuji Apples 3 lb     100000000003
# 3           4        Navel Oranges 4 lb     100000000004
# 4           5  Red Seedless Grapes 2 lb     100000000005
#
#        product_description  category_id
# 0     Fresh yellow bananas            1
# 1    Sweet gala apples bag            1
# 2    Crisp fuji apples bag            1
# 3  Juicy navel oranges bag            1
# 4      Seedless red grapes            1

# %%
card_details = pd.read_csv('../Project/Datasets/card_details.csv')
card_details.head()
# Out:
#    card_id       card_name  last_4_digits    exp_date  customer_id
# 0        1     Emma Parker           6212  2031-06-01            1
# 1        2     Liam Murphy           3621  2031-08-01            2
# 2        3  Olivia Collins            320  2031-11-01            3
# 3        4       Noah Reed           9652  2029-11-01            4
# 4        5     Ava Bennett           6040  2031-05-01            5

# %%
customer = pd.read_csv('../Project/Datasets/customer.csv')
customer.head()
# Out:
#    customer_id            name                      email    password  \
# 0            1     Emma Parker     emma.parker1@gmail.com    emma@123
# 1            2     Liam Murphy   liam.murphy2@outlook.com    liam@123
# 2            3  Olivia Collins  olivia.collins3@yahoo.com  olivia@123
# 3            4       Noah Reed      noah.reed4@icloud.com    noah@123
# 4            5     Ava Bennett     ava.bennett5@gmail.com     ava@123
#
#   date_of_birth
# 0    1983-02-01
# 1    1973-12-07
# 2    1966-02-03
# 3    1992-06-25
# 4    1976-10-07

# %%
customer_address = pd.read_csv('../Project/Datasets/customer_address.csv')
customer_address.head()
# Out:
#             street    city          state country  zip_code  customer_id
# 0    616 Beacon St  Quincy  Massachusetts     USA      2169            1
# 1  283 Pleasant St  Boston  Massachusetts     USA      2108            2
# 2    737 Summer St  Quincy  Massachusetts     USA      2169            3
# 3   68 Chestnut St  Boston  Massachusetts     USA      2108            4
# 4     762 Park Ave  Malden  Massachusetts     USA      2148            5

# %%
order_confirmation = pd.read_csv('../Project/Datasets/order_confirmation.csv')
order_confirmation.head()
# Out:
#    order_id  payment_id  delivery_id confirmation_status
# 0         1           1          NaN           confirmed
# 1         2           2          NaN           confirmed
# 2         3           3          NaN       not confirmed
# 3         4           4          NaN           confirmed
# 4         5           5          NaN       not confirmed

# %%
order_items = pd.read_csv('../Project/Datasets/order_items.csv')
order_items.head()
# Out:
#    quantity  price_at_purchase  order_id  product_id
# 0         1               1.07         1          36
# 1         1               4.18         2         188
# 2         4               0.90         2         115
# 3         2               6.57         2         135
# 4         3               4.95         2         106

# %%
orders = pd.read_csv('../Project/Datasets/orders.csv')
orders.head()
# Out:
#    order_id order_type           order_time  order_date order_status  \
# 0         1   Delivery  2026-02-12 05:54:29  2026-02-12    Confirmed
# 1         2   Delivery  2026-02-04 13:09:54  2026-02-04    Confirmed
# 2         3   Delivery  2026-02-07 03:56:00  2026-02-07    Cancelled
# 3         4   Delivery  2026-03-05 10:27:24  2026-03-05    Confirmed
# 4         5   Delivery  2026-02-22 00:41:26  2026-02-22       Failed
#
#    customer_id  store_id
# 0            2         8
# 1           18         3
# 2           75         9
# 3           48         4
# 4           62         6

# %%
payment = pd.read_csv('../Project/Datasets/payments.csv')
payment.head()
# Out:
#    payment_id payment_method payment_status  total_amount payment_date  \
# 0           1         paypal        Success          1.07   2026-02-12
# 1           2    credit card        Success         48.45   2026-02-04
# 2           3     debit card         Failed         50.12   2026-02-07
# 3           4     debit card        Success         20.85   2026-03-05
# 4           5    credit card         Failed         35.21   2026-02-22
#
#    card_id
# 0      NaN
# 1     18.0
# 2     75.0
# 3     48.0
# 4     62.0

# %%
product_price = pd.read_csv('../Project/Datasets/product_price.csv')
product_price.head()
# Out:
#    price_id  market_price  current_retail_price  discounted_price  \
# 0         1          4.12                  3.78               NaN
# 1         2          6.48                  6.21               NaN
# 2         3          5.65                  5.12               NaN
# 3         4          2.21                  1.55              1.37
# 4         5          4.91                  4.65               NaN
#
#   is_discounted last_update_date  product_id
# 0            no       2026-03-29           1
# 1            no       2026-03-29           2
# 2            no       2026-03-29           3
# 3           yes       2026-03-29           4
# 4            no       2026-03-29           5

# %%
delivery_address = pd.read_csv('../Project/Datasets/delivery_address.csv')
delivery_address.head()
# Out:
#             street       city          state country  zip_code  delivery_id
# 0     474 Broadway    Medford  Massachusetts     USA      2155            1
# 1       640 Oak St     Quincy  Massachusetts     USA      2169            2
# 2     990 Cedar St     Boston  Massachusetts     USA      2108            3
# 3  751 Franklin St     Boston  Massachusetts     USA      2108            4
# 4     447 River St  Brookline  Massachusetts     USA      2445            5

# %%
delivery_details = pd.read_csv('../Project/Datasets/delivery_details.csv')
delivery_details.head()
# Out:
#    delivery_id delivery_status delivery_date
# 0            1   not delivered    2026-02-15
# 1            2   not delivered    2026-02-06
# 2            3   not delivered    2026-02-08
# 3            4       delivered    2026-03-07
# 4            5   not delivered    2026-02-25

# %%
order_assignment = pd.read_csv('../Project/Datasets/order_assignment.csv')
order_assignment.head()
# Out:
#    assignment_id   assignment_status  manager_id  packer_id  order_id
# 0              1           confirmed          29         31         1
# 1              2  Ready for delivery           9         11         2
# 2              3           confirmed          33         36         3
# 3              4           delivered          13         15         4
# 4              5           confirmed          21         23         5

# %% [markdown]
# # database connection

# %%
import mysql.connector

# %%
database = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'Bubllo@0299',
    database = 'supermarket'
)

# %%
if database.is_connected():
    print("Connected to MySQL database")
else:
    print("Failed to connect to MySQL database")
# Out:
# Connected to MySQL database

# %% [markdown]
# ## creating cursor to navigate

# %%
cursor = database.cursor()

# %% [markdown]
# ## Display all table

# %%
cursor.execute("SHOW TABLES")

# %%
for i in cursor:
    print(i)
# Out:
# ('card_details',)
# ('category',)
# ('customer',)
# ('customer_address',)
# ('customer_order',)
# ('delivery_address',)
# ('delivery_details',)
# ('inventory',)
# ('order_assignment',)
# ('order_confirmation',)
# ('order_items',)
# ('payment',)
# ('product',)
# ('product_images',)
# ('product_price',)
# ('store_address',)
# ('store_details',)
# ('store_manager',)
# ('store_staff',)
# ('store_staff_packer',)
# ('stores',)

# %% [markdown]
# ## Inserting stores details

# %%
store_details
# Out:
#    store_id                  store_name       phone  \
# 0         1          FreshMart Downtown  6175551001
# 1         2         FreshMart Riverside  6175551002
# 2         3          GreenBasket Market  6175551003
# 3         4      UrbanGrocers South End  6175551004
# 4         5         QuickCart Brookline  6175551005
# 5         6             CityFresh Salem  6175551006
# 6         7           ValueMart Medford  6175551007
# 7         8  Neighborhood Market Quincy  6175551008
# 8         9        FamilyGrocers Newton  6175551009
# 9        10           SuperSaver Revere  6175551010
#
#                            email
# 0         downtown@freshmart.com
# 1        riverside@freshmart.com
# 2    hello@greenbasketmarket.com
# 3      southend@urbangrocers.com
# 4        brookline@quickcart.com
# 5            salem@cityfresh.com
# 6          medford@valuemart.com
# 7  quincy@neighborhoodmarket.com
# 8       newton@familygrocers.com
# 9          revere@supersaver.com

# %%
query = "INSERT INTO store_details (store_id, store_name, phone, email) VALUES (%s,%s,%s,%s)"
data = list(store_details.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM store_details")
for i in cursor:
    print(i)
# Out:
# (1, 'FreshMart Downtown', '6175551001', 'downtown@freshmart.com')
# (2, 'FreshMart Riverside', '6175551002', 'riverside@freshmart.com')
# (3, 'GreenBasket Market', '6175551003', 'hello@greenbasketmarket.com')
# (4, 'UrbanGrocers South End', '6175551004', 'southend@urbangrocers.com')
# (5, 'QuickCart Brookline', '6175551005', 'brookline@quickcart.com')
# (6, 'CityFresh Salem', '6175551006', 'salem@cityfresh.com')
# (7, 'ValueMart Medford', '6175551007', 'medford@valuemart.com')
# (8, 'Neighborhood Market Quincy', '6175551008', 'quincy@neighborhoodmarket.com')
# (9, 'FamilyGrocers Newton', '6175551009', 'newton@familygrocers.com')
# (10, 'SuperSaver Revere', '6175551010', 'revere@supersaver.com')

# %% [markdown]
# ## Store Address

# %%
store_address
# Out:
#             street        city          state country  zip_code  store_id
# 0      101 Main St      Boston  Massachusetts     USA      2108         1
# 1      22 River Rd   Cambridge  Massachusetts     USA      2139         2
# 2    15 Beacon Ave  Somerville  Massachusetts     USA      2143         3
# 3  88 Harrison Ave      Boston  Massachusetts     USA      2118         4
# 4       200 Elm St   Brookline  Massachusetts     USA      2445         5
# 5      43 Union St       Salem  Massachusetts     USA      1970         6
# 6        77 Oak St     Medford  Massachusetts     USA      2155         7
# 7    19 Walnut Ave      Quincy  Massachusetts     USA      2169         8
# 8    305 Centre St      Newton  Massachusetts     USA      2458         9
# 9    12 Harbor Way      Revere  Massachusetts     USA      2151        10

# %%
query = "INSERT INTO store_address (Street, City, State, Country, zip_code, store_id) VALUES (%s,%s,%s,%s,%s, %s)"
data = list(store_address.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM store_address")
for i in cursor:
    print(i)
# Out:
# ('101 Main St', 'Boston', 'Massachusetts', 'USA', '2108', 1)
# ('22 River Rd', 'Cambridge', 'Massachusetts', 'USA', '2139', 2)
# ('15 Beacon Ave', 'Somerville', 'Massachusetts', 'USA', '2143', 3)
# ('88 Harrison Ave', 'Boston', 'Massachusetts', 'USA', '2118', 4)
# ('200 Elm St', 'Brookline', 'Massachusetts', 'USA', '2445', 5)
# ('43 Union St', 'Salem', 'Massachusetts', 'USA', '1970', 6)
# ('77 Oak St', 'Medford', 'Massachusetts', 'USA', '2155', 7)
# ('19 Walnut Ave', 'Quincy', 'Massachusetts', 'USA', '2169', 8)
# ('305 Centre St', 'Newton', 'Massachusetts', 'USA', '2458', 9)
# ('12 Harbor Way', 'Revere', 'Massachusetts', 'USA', '2151', 10)

# %%
inventory
# Out:
#       inventory_id  quantity_available  reorder_level last_updated
# 0                1                   5              4   2026-03-29
# 1                2                  36              4   2026-03-29
# 2                3                  33              4   2026-03-29
# 3                4                  30              4   2026-03-29
# 4                5                  24              4   2026-03-29
# ...            ...                 ...            ...          ...
# 2395          2396                  48              1   2026-03-29
# 2396          2397                  26              1   2026-03-29
# 2397          2398                  34              2   2026-03-29
# 2398          2399                  49              1   2026-03-29
# 2399          2400                  59              2   2026-03-29
#
# [2400 rows x 4 columns]

# %%
query = "INSERT INTO inventory (inventory_id, quantity_available, reorder_level, last_updated) VALUES (%s,%s,%s,%s)"
data = list(inventory.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM inventory")
for i in cursor:
    print(i)
# Out:
# (1, 5, 4, datetime.date(2026, 3, 29))
# (2, 36, 4, datetime.date(2026, 3, 29))
# (3, 33, 4, datetime.date(2026, 3, 29))
# (4, 30, 4, datetime.date(2026, 3, 29))
# (5, 24, 4, datetime.date(2026, 3, 29))
# (6, 14, 4, datetime.date(2026, 3, 29))
# (7, 31, 4, datetime.date(2026, 3, 29))
# (8, 27, 4, datetime.date(2026, 3, 29))
# (9, 29, 4, datetime.date(2026, 3, 29))
# (10, 25, 4, datetime.date(2026, 3, 29))
# (11, 12, 4, datetime.date(2026, 3, 29))
# (12, 26, 4, datetime.date(2026, 3, 29))
# (13, 5, 4, datetime.date(2026, 3, 29))
# (14, 25, 4, datetime.date(2026, 3, 29))
# (15, 26, 4, datetime.date(2026, 3, 29))
# (16, 30, 4, datetime.date(2026, 3, 29))
# (17, 12, 4, datetime.date(2026, 3, 29))
# (18, 17, 4, datetime.date(2026, 3, 29))
# (19, 5, 4, datetime.date(2026, 3, 29))
# (20, 23, 4, datetime.date(2026, 3, 29))
# (21, 21, 4, datetime.date(2026, 3, 29))
# (22, 28, 4, datetime.date(2026, 3, 29))
# (23, 9, 4, datetime.date(2026, 3, 29))
# (24, 30, 4, datetime.date(2026, 3, 29))
# ...

# %%
product
# Out:
#      product_id                   product_name  product_barcode  \
# 0             1                   Banana Bunch     100000000001
# 1             2               Gala Apples 3 lb     100000000002
# 2             3               Fuji Apples 3 lb     100000000003
# 3             4             Navel Oranges 4 lb     100000000004
# 4             5       Red Seedless Grapes 2 lb     100000000005
# ..          ...                            ...              ...
# 235         236       Bran Crunch Cereal 16 oz     100000000236
# 236         237      Cinnamon Bagel Chips 7 oz     100000000237
# 237         238  Honey Breakfast Biscuits 5 ct     100000000238
# 238         239             Chia Oat Cups 4 ct     100000000239
# 239         240      Protein Pancake Mix 20 oz     100000000240
#
#          product_description  category_id
# 0       Fresh yellow bananas            1
# 1      Sweet gala apples bag            1
# 2      Crisp fuji apples bag            1
# ...

# %% [markdown]
# ## categories

# %%
category
# Out:
#     category_id        category_name  \
# 0             1               Fruits
# 1             2           Vegetables
# 2             3                Dairy
# 3             4               Bakery
# 4             5       Meat & Seafood
# 5             6            Beverages
# 6             7               Snacks
# 7             8         Frozen Foods
# 8             9            Household
# 9            10        Personal Care
# 10           11       Pantry Staples
# 11           12  Breakfast & Cereals
#
#                                  category_description
# 0                               Fresh seasonal fruits
# 1                      Fresh produce and leafy greens
# 2              Milk, yogurt, eggs, cheese, and butter
# 3          Fresh breads, rolls, muffins, and pastries
# 4                         White meat and seafood only
# 5         Juices, water, coffee, tea, and soft drinks
# 6          Chips, crackers, bars, cookies, and treats
# ...

# %%
query = "INSERT INTO category(category_id, category_name, category_description) VALUES (%s,%s,%s)"
data = list(category.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM category")
for i in cursor:
    print(i)
# Out:
# (1, 'Fruits', 'Fresh seasonal fruits')
# (2, 'Vegetables', 'Fresh produce and leafy greens')
# (3, 'Dairy', 'Milk, yogurt, eggs, cheese, and butter')
# (4, 'Bakery', 'Fresh breads, rolls, muffins, and pastries')
# (5, 'Meat & Seafood', 'White meat and seafood only')
# (6, 'Beverages', 'Juices, water, coffee, tea, and soft drinks')
# (7, 'Snacks', 'Chips, crackers, bars, cookies, and treats')
# (8, 'Frozen Foods', 'Frozen meals, vegetables, desserts, and breakfast items')
# (9, 'Household', 'Cleaning supplies and home essentials')
# (10, 'Personal Care', 'Daily hygiene and health essentials')
# (11, 'Pantry Staples', 'Cooking oils, grains, canned goods, and spreads')
# (12, 'Breakfast & Cereals', 'Cereal, oats, syrups, and breakfast pantry items')

# %% [markdown]
# ## Product

# %%
query = "INSERT INTO product (product_id, product_name, product_barcode, product_description, category_id) VALUES (%s,%s,%s,%s,%s)"
data = list(product.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM product")
for i in cursor:
    print(i)
# Out:
# (1, 'Banana Bunch', '100000000001', 'Fresh yellow bananas', 1)
# (2, 'Gala Apples 3 lb', '100000000002', 'Sweet gala apples bag', 1)
# (3, 'Fuji Apples 3 lb', '100000000003', 'Crisp fuji apples bag', 1)
# (4, 'Navel Oranges 4 lb', '100000000004', 'Juicy navel oranges bag', 1)
# (5, 'Red Seedless Grapes 2 lb', '100000000005', 'Seedless red grapes', 1)
# (6, 'Green Seedless Grapes 2 lb', '100000000006', 'Seedless green grapes', 1)
# (7, 'Strawberries 1 lb', '100000000007', 'Fresh strawberries', 1)
# (8, 'Blueberries 1 pint', '100000000008', 'Fresh blueberries', 1)
# (9, 'Raspberries 6 oz', '100000000009', 'Fresh raspberries', 1)
# (10, 'Blackberries 6 oz', '100000000010', 'Fresh blackberries', 1)
# (11, 'Ataulfo Mango', '100000000011', 'Sweet ripe mango', 1)
# (12, 'Pineapple Whole', '100000000012', 'Whole ripe pineapple', 1)
# (13, 'Mini Watermelon', '100000000013', 'Seedless mini watermelon', 1)
# (14, 'Cantaloupe Whole', '100000000014', 'Fresh cantaloupe', 1)
# ...

# %% [markdown]
# # stores

# %%
store_mapping
# Out:
#       store_id  inventory_id  product_id
# 0            1             1           1
# 1            1             2           2
# 2            1             3           3
# 3            1             4           4
# 4            1             5           5
# ...        ...           ...         ...
# 2395        10          2396         236
# 2396        10          2397         237
# 2397        10          2398         238
# 2398        10          2399         239
# 2399        10          2400         240
#
# [2400 rows x 3 columns]

# %%
query = "INSERT INTO stores(store_id,inventory_id, product_id) VALUES (%s,%s,%s)"
data = list(store_mapping.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM stores")
for i in cursor:
    print(i)
# Out:
# (1, 1, 1)
# (1, 2, 2)
# (1, 3, 3)
# (1, 4, 4)
# (1, 5, 5)
# (1, 6, 6)
# (1, 7, 7)
# (1, 8, 8)
# (1, 9, 9)
# (1, 10, 10)
# (1, 11, 11)
# (1, 12, 12)
# (1, 13, 13)
# (1, 14, 14)
# (1, 15, 15)
# (1, 16, 16)
# (1, 17, 17)
# (1, 18, 18)
# (1, 19, 19)
# (1, 20, 20)
# (1, 21, 21)
# (1, 22, 22)
# (1, 23, 23)
# (1, 24, 24)
# (1, 25, 25)
# (1, 26, 26)
# (1, 27, 27)
# (1, 28, 28)
# (1, 29, 29)
# (1, 30, 30)
# (1, 31, 31)
# (1, 32, 32)
# (1, 33, 33)
# (1, 34, 34)
# (1, 35, 35)
# (1, 36, 36)
# (1, 37, 37)
# (1, 38, 38)
# (1, 39, 39)
# (1, 40, 40)
# (1, 41, 41)
# (1, 42, 42)
# (1, 43, 43)
# (1, 44, 44)
# (1, 45, 45)
# (1, 46, 46)
# (1, 47, 47)
# (1, 48, 48)
# (1, 49, 49)
# (1, 50, 50)
# (1, 51, 51)
# (1, 52, 52)
# (1, 53, 53)
# (1, 54, 54)
# (1, 55, 55)
# (1, 56, 56)
# (1, 57, 57)
# (1, 58, 58)
# (1, 59, 59)
# (1, 60, 60)
# (1, 61, 61)
# (1, 62, 62)
# (1, 63, 63)
# (1, 64, 64)
# (1, 65, 65)
# (1, 66, 66)
# (1, 67, 67)
# (1, 68, 68)
# (1, 69, 69)
# (1, 70, 70)
# (1, 71, 71)
# (1, 72, 72)
# ...

# %% [markdown]
# ## Product price

# %%
product_price
# Out:
#      price_id  market_price  current_retail_price  discounted_price  \
# 0           1          4.12                  3.78               NaN
# 1           2          6.48                  6.21               NaN
# 2           3          5.65                  5.12               NaN
# 3           4          2.21                  1.55              1.37
# 4           5          4.91                  4.65               NaN
# ..        ...           ...                   ...               ...
# 235       236          3.52                  2.64              1.20
# 236       237          3.44                  2.17               NaN
# 237       238          6.72                  5.37               NaN
# 238       239          8.41                  7.91               NaN
# 239       240         10.10                  9.27              9.09
#
#     is_discounted last_update_date  product_id
# 0              no       2026-03-29           1
# 1              no       2026-03-29           2
# ...

# %%
import numpy as np

product_price = product_price.replace({np.nan: None, "": None})

# %%
query = "INSERT INTO product_price(price_id,market_price, current_retail_price, discounted_price, is_discounted, last_update_date, product_id) VALUES (%s,%s,%s,%s,%s,%s,%s)"
data = list(product_price.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM product_price")
for i in cursor:
    print(i)
# Out:
# (1, Decimal('4.12'), Decimal('3.78'), None, 'no', datetime.date(2026, 3, 29), 1)
# (2, Decimal('6.48'), Decimal('6.21'), None, 'no', datetime.date(2026, 3, 29), 2)
# (3, Decimal('5.65'), Decimal('5.12'), None, 'no', datetime.date(2026, 3, 29), 3)
# (4, Decimal('2.21'), Decimal('1.55'), Decimal('1.37'), 'yes', datetime.date(2026, 3, 29), 4)
# (5, Decimal('4.91'), Decimal('4.65'), None, 'no', datetime.date(2026, 3, 29), 5)
# (6, Decimal('2.44'), Decimal('1.86'), None, 'no', datetime.date(2026, 3, 29), 6)
# (7, Decimal('7.74'), Decimal('7.43'), None, 'no', datetime.date(2026, 3, 29), 7)
# (8, Decimal('3.40'), Decimal('2.64'), Decimal('1.21'), 'yes', datetime.date(2026, 3, 29), 8)
# (9, Decimal('5.95'), Decimal('5.39'), None, 'no', datetime.date(2026, 3, 29), 9)
# (10, Decimal('8.82'), Decimal('8.58'), None, 'no', datetime.date(2026, 3, 29), 10)
# (11, Decimal('7.97'), Decimal('7.51'), None, 'no', datetime.date(2026, 3, 29), 11)
# ...

# %% [markdown]
# ## product images

# %%
product_images
# Out:
#      product_id                                          image_url  \
# 0             1                cdn.local/products/banana-bunch.jpg
# 1             2            cdn.local/products/gala-apples-3-lb.jpg
# 2             3            cdn.local/products/fuji-apples-3-lb.jpg
# 3             4          cdn.local/products/navel-oranges-4-lb.jpg
# 4             5    cdn.local/products/red-seedless-grapes-2-lb.jpg
# ..          ...                                                ...
# 235         236    cdn.local/products/bran-crunch-cereal-16-oz.jpg
# 236         237   cdn.local/products/cinnamon-bagel-chips-7-oz.jpg
# 237         238  cdn.local/products/honey-breakfast-biscuits-5-...
# 238         239          cdn.local/products/chia-oat-cups-4-ct.jpg
# 239         240   cdn.local/products/protein-pancake-mix-20-oz.jpg
#
#                                image_description
# 0                     Banana Bunch product image
# 1                 Gala Apples 3 lb product image
# ...

# %%
query = "INSERT INTO product_images(product_id, image_url, image_description) VALUES (%s,%s,%s)"
data = list(product_images.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM product_images")
for i in cursor:
    print(i)
# Out:
# (1, 'cdn.local/products/banana-bunch.jpg', 'Banana Bunch product image')
# (2, 'cdn.local/products/gala-apples-3-lb.jpg', 'Gala Apples 3 lb product image')
# (3, 'cdn.local/products/fuji-apples-3-lb.jpg', 'Fuji Apples 3 lb product image')
# (4, 'cdn.local/products/navel-oranges-4-lb.jpg', 'Navel Oranges 4 lb product image')
# (5, 'cdn.local/products/red-seedless-grapes-2-lb.jpg', 'Red Seedless Grapes 2 lb product image')
# (6, 'cdn.local/products/green-seedless-grapes-2-lb.jpg', 'Green Seedless Grapes 2 lb product image')
# (7, 'cdn.local/products/strawberries-1-lb.jpg', 'Strawberries 1 lb product image')
# (8, 'cdn.local/products/blueberries-1-pint.jpg', 'Blueberries 1 pint product image')
# (9, 'cdn.local/products/raspberries-6-oz.jpg', 'Raspberries 6 oz product image')
# (10, 'cdn.local/products/blackberries-6-oz.jpg', 'Blackberries 6 oz product image')
# (11, 'cdn.local/products/ataulfo-mango.jpg', 'Ataulfo Mango product image')
# ...

# %% [markdown]
# ## Store staff

# %%
store_staff
# Out:
#     emp_id           username password  store_id     role availability_status
# 0        1      olivia.parker  pass123         1  manager                 yes
# 1        2       chloe.martin  pass123         1   packer                 yes
# 2        3       jacob.turner  pass123         1   packer                 yes
# 3        4         grace.ward  pass123         1   packer                 yes
# 4        5      daniel.murphy  pass123         2  manager                 yes
# 5        6         mason.bell  pass123         2   packer                 yes
# 6        7          zoe.kelly  pass123         2   packer                 yes
# 7        8         henry.cook  pass123         2   packer                 yes
# 8        9     sophia.collins  pass123         3  manager                 yes
# 9       10        nora.bailey  pass123         3   packer                 yes
# 10      11       logan.cooper  pass123         3   packer                 yes
# ...

# %%
store_staff_details = store_staff[['emp_id','username','password','store_id']]
store_staff_details.head()
# Out:
#    emp_id       username password  store_id
# 0       1  olivia.parker  pass123         1
# 1       2   chloe.martin  pass123         1
# 2       3   jacob.turner  pass123         1
# 3       4     grace.ward  pass123         1
# 4       5  daniel.murphy  pass123         2

# %%
query = "INSERT INTO store_staff(emp_id, username, password, store_id) VALUES (%s,%s,%s,%s)"
data = list(store_staff_details.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM store_staff")
for i in cursor:
    print(i)
# Out:
# (1, 'olivia.parker', 'pass123', 1)
# (2, 'chloe.martin', 'pass123', 1)
# (3, 'jacob.turner', 'pass123', 1)
# (4, 'grace.ward', 'pass123', 1)
# (5, 'daniel.murphy', 'pass123', 2)
# (6, 'mason.bell', 'pass123', 2)
# (7, 'zoe.kelly', 'pass123', 2)
# (8, 'henry.cook', 'pass123', 2)
# (9, 'sophia.collins', 'pass123', 3)
# (10, 'nora.bailey', 'pass123', 3)
# (11, 'logan.cooper', 'pass123', 3)
# (12, 'lily.rivera', 'pass123', 3)
# (13, 'ethan.reed', 'pass123', 4)
# (14, 'elijah.morris', 'pass123', 4)
# (15, 'hannah.peterson', 'pass123', 4)
# (16, 'jack.gray', 'pass123', 4)
# (17, 'ava.bennett', 'pass123', 5)
# (18, 'ella.james', 'pass123', 5)
# (19, 'owen.watson', 'pass123', 5)
# (20, 'scarlett.bryant', 'pass123', 5)
# (21, 'liam.foster', 'pass123', 6)
# (22, 'levi.russell', 'pass123', 6)
# (23, 'aria.diaz', 'pass123', 6)
# (24, 'wyatt.ortiz', 'pass123', 6)
# (25, 'mia.hayes', 'pass123', 7)
# (26, 'layla.sanders', 'pass123', 7)
# (27, 'julian.powell', 'pass123', 7)
# ...

# %% [markdown]
# ## Store manager

# %%
manager_detail = store_staff[store_staff['role'] == 'manager']
manager_detail = manager_detail['emp_id']
manager_detail.head()
# Out:
# 0      1
# 4      5
# 8      9
# 12    13
# 16    17
# Name: emp_id, dtype: int64

# %%
query = "INSERT INTO store_manager(emp_id) VALUES (%s)"
data = []
for i in manager_detail:
    data.append([i])
cursor.executemany(query, data)
cursor.execute("SELECT * FROM store_manager")
for i in cursor:
    print(i)
# Out:
# (1,)
# (5,)
# (9,)
# (13,)
# (17,)
# (21,)
# (25,)
# (29,)
# (33,)
# (37,)

# %% [markdown]
# ## Packer

# %%
packer_detail = store_staff[store_staff['role'] == 'packer']
packer_detail = packer_detail[['emp_id',"availability_status"]]
packer_detail.head()
# Out:
#    emp_id availability_status
# 1       2                 yes
# 2       3                 yes
# 3       4                 yes
# 5       6                 yes
# 6       7                 yes

# %%
query = "INSERT INTO store_staff_packer(emp_id,Availability_status) VALUES (%s,%s)"
data = list(packer_detail.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM store_staff_packer")
for i in cursor:
    print(i)
# Out:
# (2, 'yes')
# (3, 'yes')
# (4, 'yes')
# (6, 'yes')
# (7, 'yes')
# (8, 'yes')
# (10, 'yes')
# (11, 'yes')
# (12, 'yes')
# (14, 'yes')
# (15, 'yes')
# (16, 'yes')
# (18, 'yes')
# (19, 'yes')
# (20, 'yes')
# (22, 'yes')
# (23, 'yes')
# (24, 'yes')
# (26, 'yes')
# (27, 'yes')
# (28, 'yes')
# (30, 'yes')
# (31, 'yes')
# (32, 'yes')
# (34, 'yes')
# (35, 'yes')
# (36, 'yes')
# (38, 'yes')
# (39, 'yes')
# (40, 'yes')

# %% [markdown]
# # Customer

# %%
customer[['first_name', 'last_name']] = customer['name'].str.split(' ', n=1, expand=True)
customer = customer.drop(columns=['name'])
customer = customer[['customer_id', 'first_name', 'last_name', 'email', 'password', 'date_of_birth']]

# %%
customer
# Out:
#     customer_id first_name last_name                        email  \
# 0             1       Emma    Parker       emma.parker1@gmail.com
# 1             2       Liam    Murphy     liam.murphy2@outlook.com
# 2             3     Olivia   Collins    olivia.collins3@yahoo.com
# 3             4       Noah      Reed        noah.reed4@icloud.com
# 4             5        Ava   Bennett       ava.bennett5@gmail.com
# ..          ...        ...       ...                          ...
# 95           96     Connor      Chen     connor.chen96@icloud.com
# 96           97      Elena       Lin        elena.lin97@gmail.com
# 97           98   Jonathan      Wong  jonathan.wong98@outlook.com
# 98           99       Ruby     Zhang       ruby.zhang99@yahoo.com
# 99          100   Jeremiah       Liu   jeremiah.liu100@icloud.com
#
#         password date_of_birth
# 0       emma@123    1983-02-01
# 1       liam@123    1973-12-07
# 2     olivia@123    1966-02-03
# 3       noah@123    1992-06-25
# ...

# %%
query = "INSERT INTO customer(customer_id, first_name, last_name, email, password, date_of_birth) VALUES (%s,%s,%s,%s,%s,%s)"
data = list(customer.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM customer")
for i in cursor:
    print(i)
# Out:
# (1, 'Emma', 'Parker', 'emma.parker1@gmail.com', 'emma@123', datetime.date(1983, 2, 1))
# (2, 'Liam', 'Murphy', 'liam.murphy2@outlook.com', 'liam@123', datetime.date(1973, 12, 7))
# (3, 'Olivia', 'Collins', 'olivia.collins3@yahoo.com', 'olivia@123', datetime.date(1966, 2, 3))
# (4, 'Noah', 'Reed', 'noah.reed4@icloud.com', 'noah@123', datetime.date(1992, 6, 25))
# (5, 'Ava', 'Bennett', 'ava.bennett5@gmail.com', 'ava@123', datetime.date(1976, 10, 7))
# (6, 'Elijah', 'Foster', 'elijah.foster6@outlook.com', 'elijah@123', datetime.date(1985, 10, 3))
# (7, 'Sophia', 'Hayes', 'sophia.hayes7@yahoo.com', 'sophia@123', datetime.date(1975, 3, 26))
# (8, 'Lucas', 'Brooks', 'lucas.brooks8@icloud.com', 'lucas@123', datetime.date(1972, 2, 4))
# (9, 'Isabella', 'Sullivan', 'isabella.sullivan9@gmail.com', 'isabella@123', datetime.date(2002, 6, 4))
# (10, 'Mason', 'Price', 'mason.price10@outlook.com', 'mason@123', datetime.date(1978, 5, 5))
# ...

# %% [markdown]
# ## Customer Address

# %%
customer_address
# Out:
#               street        city          state country  zip_code  customer_id
# 0      616 Beacon St      Quincy  Massachusetts     USA      2169            1
# 1    283 Pleasant St      Boston  Massachusetts     USA      2108            2
# 2      737 Summer St      Quincy  Massachusetts     USA      2169            3
# 3     68 Chestnut St      Boston  Massachusetts     USA      2108            4
# 4       762 Park Ave      Malden  Massachusetts     USA      2148            5
# ..               ...         ...            ...     ...       ...          ...
# 95      656 Broadway      Quincy  Massachusetts     USA      2169           96
# 96   239 Chestnut St      Quincy  Massachusetts     USA      2169           97
# 97      63 Summer St       Salem  Massachusetts     USA      1970           98
# 98     359 Walnut St      Revere  Massachusetts     USA      2151           99
# 99  219 Highland Ave  Somerville  Massachusetts     USA      2143          100
#
# [100 rows x 6 columns]

# %%
query= "INSERT INTO customer_address (street, city, state, country, zip_code, customer_id) VALUES (%s,%s,%s,%s,%s,%s)"
data = list(customer_address.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM customer_address")
for i in cursor:
    print(i)
# Out:
# ('616 Beacon St', 'Quincy', 'Massachusetts', 'USA', '2169', 1)
# ('283 Pleasant St', 'Boston', 'Massachusetts', 'USA', '2108', 2)
# ('737 Summer St', 'Quincy', 'Massachusetts', 'USA', '2169', 3)
# ('68 Chestnut St', 'Boston', 'Massachusetts', 'USA', '2108', 4)
# ('762 Park Ave', 'Malden', 'Massachusetts', 'USA', '2148', 5)
# ('843 Summer St', 'Somerville', 'Massachusetts', 'USA', '2143', 6)
# ('192 Franklin St', 'Medford', 'Massachusetts', 'USA', '2155', 7)
# ('446 Oak St', 'Malden', 'Massachusetts', 'USA', '2148', 8)
# ('388 Beacon St', 'Revere', 'Massachusetts', 'USA', '2151', 9)
# ('119 Massachusetts Ave', 'Cambridge', 'Massachusetts', 'USA', '2139', 10)
# ('616 Cedar St', 'Quincy', 'Massachusetts', 'USA', '2169', 11)
# ('412 Maple St', 'Somerville', 'Massachusetts', 'USA', '2143', 12)
# ('776 Pine St', 'Medford', 'Massachusetts', 'USA', '2155', 13)
# ('280 Pleasant St', 'Revere', 'Massachusetts', 'USA', '2151', 14)
# ...

# %% [markdown]
# ## Customer card details

# %%
card_details[['first_name', 'last_name']] = card_details['card_name'].str.split(' ', n=1, expand=True)
card_details = card_details.drop(columns=['card_name'])
card_details = card_details[['card_id', 'first_name', 'last_name', 'last_4_digits', 'exp_date', 'customer_id']]

# %%
card_details
# Out:
#     card_id first_name last_name  last_4_digits    exp_date  customer_id
# 0         1       Emma    Parker           6212  2031-06-01            1
# 1         2       Liam    Murphy           3621  2031-08-01            2
# 2         3     Olivia   Collins            320  2031-11-01            3
# 3         4       Noah      Reed           9652  2029-11-01            4
# 4         5        Ava   Bennett           6040  2031-05-01            5
# ..      ...        ...       ...            ...         ...          ...
# 95       96     Connor      Chen           6667  2028-10-01           96
# 96       97      Elena       Lin           1806  2031-02-01           97
# 97       98   Jonathan      Wong           1243  2030-02-01           98
# 98       99       Ruby     Zhang           6292  2027-12-01           99
# 99      100   Jeremiah       Liu           2284  2031-03-01          100
#
# [100 rows x 6 columns]

# %%
query = "INSERT INTO card_details (card_id, first_name, last_name, last_4_digits, exp_date, customer_id) VALUES (%s,%s,%s,%s,%s,%s)"
data = list(card_details.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM card_details")
for i in cursor:
    print(i)
# Out:
# (1, 'Emma', 'Parker', '6212', datetime.date(2031, 6, 1), 1)
# (2, 'Liam', 'Murphy', '3621', datetime.date(2031, 8, 1), 2)
# (3, 'Olivia', 'Collins', '320', datetime.date(2031, 11, 1), 3)
# (4, 'Noah', 'Reed', '9652', datetime.date(2029, 11, 1), 4)
# (5, 'Ava', 'Bennett', '6040', datetime.date(2031, 5, 1), 5)
# (6, 'Elijah', 'Foster', '7914', datetime.date(2031, 8, 1), 6)
# (7, 'Sophia', 'Hayes', '8520', datetime.date(2028, 10, 1), 7)
# (8, 'Lucas', 'Brooks', '4514', datetime.date(2031, 5, 1), 8)
# (9, 'Isabella', 'Sullivan', '4993', datetime.date(2030, 9, 1), 9)
# (10, 'Mason', 'Price', '8077', datetime.date(2028, 6, 1), 10)
# (11, 'Mia', 'Martin', '2740', datetime.date(2030, 1, 1), 11)
# (12, 'Ethan', 'Turner', '3696', datetime.date(2027, 4, 1), 12)
# (13, 'Charlotte', 'Ward', '261', datetime.date(2030, 8, 1), 13)
# (14, 'James', 'Bell', '3221', datetime.date(2030, 5, 1), 14)
# (15, 'Amelia', 'Kelly', '2780', datetime.date(2031, 9, 1), 15)
# ...

# %% [markdown]
# # orders

# %%
orders
# Out:
#      order_id order_type           order_time  order_date order_status  \
# 0           1   Delivery  2026-02-12 05:54:29  2026-02-12    Confirmed
# 1           2   Delivery  2026-02-04 13:09:54  2026-02-04    Confirmed
# 2           3   Delivery  2026-02-07 03:56:00  2026-02-07    Cancelled
# 3           4   Delivery  2026-03-05 10:27:24  2026-03-05    Confirmed
# 4           5   Delivery  2026-02-22 00:41:26  2026-02-22       Failed
# ..        ...        ...                  ...         ...          ...
# 215       216   Delivery  2026-02-13 14:51:49  2026-02-13    Cancelled
# 216       217   Delivery  2026-03-09 13:01:32  2026-03-09    Confirmed
# 217       218   Delivery  2026-03-08 10:43:19  2026-03-08    Confirmed
# 218       219     Pickup  2026-03-12 04:54:18  2026-03-12    Confirmed
# 219       220   Delivery  2026-03-01 05:53:19  2026-03-01    Confirmed
#
#      customer_id  store_id
# 0              2         8
# 1             18         3
# 2             75         9
# ...

# %%
import datetime as dt
orders['order_time'] = pd.to_datetime(orders['order_time']).dt.time
orders.head()
# Out:
#    order_id order_type order_time  order_date order_status  customer_id  \
# 0         1   Delivery   05:54:29  2026-02-12    Confirmed            2
# 1         2   Delivery   13:09:54  2026-02-04    Confirmed           18
# 2         3   Delivery   03:56:00  2026-02-07    Cancelled           75
# 3         4   Delivery   10:27:24  2026-03-05    Confirmed           48
# 4         5   Delivery   00:41:26  2026-02-22       Failed           62
#
#    store_id
# 0         8
# 1         3
# 2         9
# 3         4
# 4         6

# %%
query = "INSERT INTO customer_order(order_id, order_type, order_time, order_date, order_status, customer_id, store_id) VALUES (%s,%s,%s,%s,%s,%s,%s)"
data = list(orders.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM customer_order")
for i in cursor:
    print(i)
# Out:
# (1, 'Delivery', datetime.timedelta(seconds=21269), datetime.date(2026, 2, 12), 'Confirmed', 2, 8)
# (2, 'Delivery', datetime.timedelta(seconds=47394), datetime.date(2026, 2, 4), 'Confirmed', 18, 3)
# (3, 'Delivery', datetime.timedelta(seconds=14160), datetime.date(2026, 2, 7), 'Cancelled', 75, 9)
# (4, 'Delivery', datetime.timedelta(seconds=37644), datetime.date(2026, 3, 5), 'Confirmed', 48, 4)
# (5, 'Delivery', datetime.timedelta(seconds=2486), datetime.date(2026, 2, 22), 'Failed', 62, 6)
# (6, 'Delivery', datetime.timedelta(seconds=171), datetime.date(2026, 3, 3), 'Failed', 52, 5)
# (7, 'Pickup', datetime.timedelta(seconds=27965), datetime.date(2026, 2, 27), 'Failed', 92, 2)
# (8, 'Delivery', datetime.timedelta(seconds=82983), datetime.date(2026, 2, 6), 'Confirmed', 20, 8)
# (9, 'Pickup', datetime.timedelta(seconds=62212), datetime.date(2026, 2, 3), 'Confirmed', 89, 8)
# (10, 'Delivery', datetime.timedelta(seconds=15635), datetime.date(2026, 2, 19), 'Confirmed', 25, 5)
# ...

# %% [markdown]
# ## Order Assignment

# %%
order_assignment
# Out:
#      assignment_id   assignment_status  manager_id  packer_id  order_id
# 0                1           confirmed          29         31         1
# 1                2  Ready for delivery           9         11         2
# 2                3           confirmed          33         36         3
# 3                4           delivered          13         15         4
# 4                5           confirmed          21         23         5
# ..             ...                 ...         ...        ...       ...
# 215            216           confirmed           5          8       216
# 216            217           delivered           1          2       217
# 217            218             packing           5          7       218
# 218            219             packing          33         34       219
# 219            220           delivered          17         19       220
#
# [220 rows x 5 columns]

# %%
query = "INSERT INTO order_assignment(assignment_id, assignment_status, manager_id, packer_id, order_id) VALUES (%s,%s,%s,%s,%s)"
data = list(order_assignment.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM order_assignment")
for i in cursor:
    print(i)
# Out:
# (1, 'confirmed', 29, 31, 1)
# (2, 'Ready for delivery', 9, 11, 2)
# (3, 'confirmed', 33, 36, 3)
# (4, 'delivered', 13, 15, 4)
# (5, 'confirmed', 21, 23, 5)
# (6, 'confirmed', 17, 20, 6)
# (7, 'confirmed', 5, 6, 7)
# (8, 'packing', 29, 32, 8)
# (9, 'Ready for pickup', 29, 32, 9)
# (10, 'packing', 17, 18, 10)
# (11, 'confirmed', 25, 27, 11)
# (12, 'confirmed', 17, 19, 12)
# (13, 'Ready for pickup', 5, 6, 13)
# (14, 'packing', 17, 19, 14)
# (15, 'Ready for pickup', 13, 15, 15)
# (16, 'Ready for pickup', 1, 3, 16)
# (17, 'Ready for pickup', 33, 34, 17)
# (18, 'packing', 17, 19, 18)
# (19, 'out for delivery', 21, 24, 19)
# (20, 'confirmed', 25, 28, 20)
# (21, 'delivered', 21, 24, 21)
# (22, 'out for delivery', 13, 16, 22)
# (23, 'Ready for delivery', 13, 16, 23)
# (24, 'delivered', 17, 19, 24)
# (25, 'packing', 13, 16, 25)
# (26, 'delivered', 37, 39, 26)
# (27, 'packing', 13, 16, 27)
# (28, 'confirmed', 5, 7, 28)
# (29, 'packing', 5, 6, 29)
# (30, 'packing', 21, 22, 30)
# ...

# %% [markdown]
# ## order items

# %%
order_items
# Out:
#      quantity  price_at_purchase  order_id  product_id
# 0           1               1.07         1          36
# 1           1               4.18         2         188
# 2           4               0.90         2         115
# 3           2               6.57         2         135
# 4           3               4.95         2         106
# ..        ...                ...       ...         ...
# 740         2               7.87       220         212
# 741         4               7.07       220         190
# 742         2              10.04       220         149
# 743         3              12.83       220         176
# 744         3               3.74       220          15
#
# [745 rows x 4 columns]

# %%
query = "INSERT INTO order_items(quantity, price_at_purchase, order_id, product_id) VALUES (%s,%s,%s,%s)"
data = list(order_items.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM order_items")
for i in cursor:
    print(i)
# Out:
# (1, Decimal('1.07'), 1, 36)
# (2, Decimal('6.34'), 2, 53)
# (3, Decimal('4.95'), 2, 106)
# (4, Decimal('0.90'), 2, 115)
# (2, Decimal('6.57'), 2, 135)
# (1, Decimal('4.18'), 2, 188)
# (4, Decimal('2.89'), 3, 35)
# (2, Decimal('5.94'), 3, 38)
# (4, Decimal('6.67'), 3, 53)
# (3, Decimal('6.95'), 4, 68)
# (2, Decimal('3.49'), 5, 46)
# (3, Decimal('7.19'), 5, 144)
# (3, Decimal('2.22'), 5, 230)
# (2, Decimal('3.79'), 6, 30)
# (4, Decimal('8.56'), 6, 117)
# (2, Decimal('7.64'), 7, 50)
# (1, Decimal('16.81'), 8, 96)
# (4, Decimal('10.31'), 8, 157)
# (4, Decimal('6.70'), 8, 221)
# (1, Decimal('4.82'), 9, 3)
# (1, Decimal('2.18'), 9, 25)
# (4, Decimal('6.78'), 9, 61)
# (4, Decimal('5.51'), 9, 90)
# (3, Decimal('9.68'), 10, 103)
# (3, Decimal('4.80'), 10, 129)
# (2, Decimal('6.71'), 10, 135)
# (4, Decimal('8.42'), 10, 182)
# (4, Decimal('6.46'), 10, 221)
# (4, Decimal('7.31'), 11, 31)
# (3, Decimal('2.15'), 11, 37)
# (2, Decimal('7.42'), 11, 54)
# (1, Decimal('3.70'), 11, 63)
# ...

# %% [markdown]
# # payment

# %%
payment
# Out:
#      payment_id payment_method payment_status  total_amount payment_date  \
# 0             1         paypal        Success          1.07   2026-02-12
# 1             2    credit card        Success         48.45   2026-02-04
# 2             3     debit card         Failed         50.12   2026-02-07
# 3             4     debit card        Success         20.85   2026-03-05
# 4             5    credit card         Failed         35.21   2026-02-22
# ..          ...            ...            ...           ...          ...
# 215         216    credit card         Failed         84.19   2026-02-13
# 216         217    credit card        Success         41.02   2026-03-09
# 217         218      apple pay        Success         18.56   2026-03-08
# 218         219         paypal        Success         62.46   2026-03-12
# 219         220      apple pay        Success        135.35   2026-03-01
#
#      card_id
# 0        NaN
# 1       18.0
# 2       75.0
# 3       48.0
# 4       62.0
# ...

# %%
data = [
    tuple(None if pd.isna(item) else item for item in row) 
    for row in payment.itertuples(index=False, name=None)
]
query = "INSERT INTO payment(payment_id, payment_method, payment_status, total_amount, payment_date, card_id) VALUES (%s,%s,%s,%s,%s,%s)"
cursor.executemany(query, data)
cursor.execute("SELECT * FROM payment")
for i in cursor:
    print(i)
# Out:
# (1, 'paypal', 'Success', Decimal('1.07'), datetime.date(2026, 2, 12), None)
# (2, 'credit card', 'Success', Decimal('48.45'), datetime.date(2026, 2, 4), 18)
# (3, 'debit card', 'Failed', Decimal('50.12'), datetime.date(2026, 2, 7), 75)
# (4, 'debit card', 'Success', Decimal('20.85'), datetime.date(2026, 3, 5), 48)
# (5, 'credit card', 'Failed', Decimal('35.21'), datetime.date(2026, 2, 22), 62)
# (6, 'credit card', 'Failed', Decimal('41.82'), datetime.date(2026, 3, 3), 52)
# (7, 'paypal', 'Failed', Decimal('15.28'), datetime.date(2026, 2, 27), None)
# (8, 'paypal', 'Success', Decimal('84.85'), datetime.date(2026, 2, 6), None)
# (9, 'apple pay', 'Success', Decimal('56.16'), datetime.date(2026, 2, 3), None)
# (10, 'google pay', 'Success', Decimal('116.38'), datetime.date(2026, 2, 19), None)
# (11, 'debit card', 'Success', Decimal('102.20'), datetime.date(2026, 3, 29), 89)
# (12, 'paypal', 'Success', Decimal('62.43'), datetime.date(2026, 3, 25), None)
# ...

# %% [markdown]
# # Delivery Details

# %% [markdown]
# ## delivery details

# %%
delivery_details
# Out:
#      delivery_id delivery_status delivery_date
# 0              1   not delivered    2026-02-15
# 1              2   not delivered    2026-02-06
# 2              3   not delivered    2026-02-08
# 3              4       delivered    2026-03-07
# 4              5   not delivered    2026-02-25
# ..           ...             ...           ...
# 128          129   not delivered    2026-03-28
# 129          130   not delivered    2026-02-15
# 130          131       delivered    2026-03-10
# 131          132   not delivered    2026-03-09
# 132          133       delivered    2026-03-03
#
# [133 rows x 3 columns]

# %%
query = "INSERT INTO delivery_details(delivery_id, delivery_status, delivery_date) VALUES (%s,%s,%s)"
data = list(delivery_details.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM delivery_details")
for i in cursor:
    print(i)
# Out:
# (1, 'not delivered', datetime.date(2026, 2, 15))
# (2, 'not delivered', datetime.date(2026, 2, 6))
# (3, 'not delivered', datetime.date(2026, 2, 8))
# (4, 'delivered', datetime.date(2026, 3, 7))
# (5, 'not delivered', datetime.date(2026, 2, 25))
# (6, 'not delivered', datetime.date(2026, 3, 6))
# (7, 'not delivered', datetime.date(2026, 2, 9))
# (8, 'not delivered', datetime.date(2026, 2, 22))
# (9, 'not delivered', datetime.date(2026, 4, 1))
# (10, 'not delivered', datetime.date(2026, 2, 28))
# (11, 'not delivered', datetime.date(2026, 3, 22))
# (12, 'not delivered', datetime.date(2026, 2, 8))
# (13, 'not delivered', datetime.date(2026, 2, 15))
# (14, 'delivered', datetime.date(2026, 2, 28))
# (15, 'not delivered', datetime.date(2026, 2, 9))
# (16, 'not delivered', datetime.date(2026, 3, 28))
# (17, 'delivered', datetime.date(2026, 2, 10))
# (18, 'not delivered', datetime.date(2026, 2, 16))
# (19, 'delivered', datetime.date(2026, 3, 2))
# ...

# %% [markdown]
# ## Delivery address

# %%
delivery_address
# Out:
#                     street       city          state country  zip_code  \
# 0             474 Broadway    Medford  Massachusetts     USA      2155
# 1               640 Oak St     Quincy  Massachusetts     USA      2169
# 2             990 Cedar St     Boston  Massachusetts     USA      2108
# 3          751 Franklin St     Boston  Massachusetts     USA      2108
# 4             447 River St  Brookline  Massachusetts     USA      2445
# ..                     ...        ...            ...     ...       ...
# 128          855 Walnut St  Brookline  Massachusetts     USA      2445
# 129  763 Massachusetts Ave      Salem  Massachusetts     USA      1970
# 130          526 Walnut St    Waltham  Massachusetts     USA      2451
# 131          686 Summer St  Cambridge  Massachusetts     USA      2139
# 132  311 Massachusetts Ave  Cambridge  Massachusetts     USA      2139
#
#      delivery_id
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...

# %%
query = "INSERT INTO delivery_address(street, city, state, country, zip_code, delivery_id) VALUES (%s,%s,%s,%s,%s,%s)"
data = list(delivery_address.itertuples(index=False, name=None))
cursor.executemany(query, data)
cursor.execute("SELECT * FROM delivery_address")
for i in cursor:
    print(i)
# Out:
# ('474 Broadway', 'Medford', 'Massachusetts', 'USA', '2155', 1)
# ('640 Oak St', 'Quincy', 'Massachusetts', 'USA', '2169', 2)
# ('990 Cedar St', 'Boston', 'Massachusetts', 'USA', '2108', 3)
# ('751 Franklin St', 'Boston', 'Massachusetts', 'USA', '2108', 4)
# ('447 River St', 'Brookline', 'Massachusetts', 'USA', '2445', 5)
# ('377 Pleasant St', 'Brookline', 'Massachusetts', 'USA', '2445', 6)
# ('371 Massachusetts Ave', 'Medford', 'Massachusetts', 'USA', '2155', 7)
# ('946 Oak St', 'Somerville', 'Massachusetts', 'USA', '2143', 8)
# ('402 Prospect St', 'Revere', 'Massachusetts', 'USA', '2151', 9)
# ('122 School St', 'Malden', 'Massachusetts', 'USA', '2148', 10)
# ('51 Summer St', 'Salem', 'Massachusetts', 'USA', '1970', 11)
# ('977 Prospect St', 'Brookline', 'Massachusetts', 'USA', '2445', 12)
# ('398 Summer St', 'Salem', 'Massachusetts', 'USA', '1970', 13)
# ('464 Maple St', 'Somerville', 'Massachusetts', 'USA', '2143', 14)
# ...

# %% [markdown]
# ## order confirmation

# %%
order_confirmation
# Out:
#      order_id  payment_id  delivery_id confirmation_status
# 0           1           1          NaN           confirmed
# 1           2           2          NaN           confirmed
# 2           3           3          NaN       not confirmed
# 3           4           4          NaN           confirmed
# 4           5           5          NaN       not confirmed
# ..        ...         ...          ...                 ...
# 215       216         216          NaN       not confirmed
# 216       217         217          NaN           confirmed
# 217       218         218          NaN           confirmed
# 218       219         219          NaN           confirmed
# 219       220         220          NaN           confirmed
#
# [220 rows x 4 columns]

# %%
query = "INSERT INTO order_confirmation(order_id, payment_id, delivery_id, confirmation_status) VALUES (%s,%s,%s,%s)"
data = [
    tuple(None if pd.isna(item) else item for item in row) 
    for row in order_confirmation.itertuples(index=False, name=None)
]
cursor.executemany(query, data)
cursor.execute("SELECT * FROM order_confirmation")
for i in cursor:
    print(i)
# Out:
# (1, 1, None, 'confirmed')
# (2, 2, None, 'confirmed')
# (3, 3, None, 'not confirmed')
# (4, 4, None, 'confirmed')
# (5, 5, None, 'not confirmed')
# (6, 6, None, 'not confirmed')
# (7, 7, None, 'not confirmed')
# (8, 8, None, 'confirmed')
# (9, 9, None, 'confirmed')
# (10, 10, None, 'confirmed')
# (11, 11, None, 'confirmed')
# (12, 12, None, 'confirmed')
# (13, 13, None, 'confirmed')
# (14, 14, None, 'confirmed')
# (15, 15, None, 'confirmed')
# (16, 16, None, 'confirmed')
# (17, 17, None, 'confirmed')
# (18, 18, None, 'confirmed')
# (19, 19, None, 'confirmed')
# (20, 20, None, 'confirmed')
# (21, 21, None, 'confirmed')
# (22, 22, None, 'confirmed')
# (23, 23, None, 'confirmed')
# (24, 24, None, 'confirmed')
# (25, 25, None, 'confirmed')
# (26, 26, None, 'confirmed')
# (27, 27, None, 'confirmed')
# (28, 28, None, 'not confirmed')
# (29, 29, None, 'confirmed')
# (30, 30, None, 'confirmed')
# (31, 31, None, 'confirmed')
# (32, 32, None, 'confirmed')
# (33, 33, None, 'not confirmed')
# ...

# %% [markdown]
# # Updating database

# %%
database.commit()

# %%
database.close()
